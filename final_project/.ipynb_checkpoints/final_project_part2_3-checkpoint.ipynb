# %% [markdown]
# ## Final Project - Part 2 + 3
# > #### Cecelia Shao
#
# > February 2018
#
#
# > From: https://github.com/ga-students/DAT-NYC-1.16.18/tree/master/projects/final-project/02-experiment-writeup
#
#
# ### Part 2: Project Design Writeup
# **Requirements:**
# - Well-articulated problem statement with "specific aim" and hypothesis, based on your lightning talk
# - An outline of any potential methods and models
# - Detailed explanation of extant data available (ie: build a data dictionary or link to pre-built data dictionaries)
# - Describe any outstanding questions, assumptions, risks, caveats
# - Demonstrate domain knowledge, including specific features or relevant benchmarks from similar projects
# - Define your goals and criteria, in order to explain what success looks like
#
# **Bonus**
#
# - Consider alternative hypotheses: if your project is a regression problem, is it possible to rewrite it as a classification problem?
# - "Convert" your goal metric from a statistical one (like Mean Squared Error) and tie it to something non-data people can understand, like a cost/benefit analysis, etc.

# %% [markdown]
# ### Project Problem and Hypothesis
# **What's the project about? What problem are you solving?**
# My project centers around potential ways to predict gentrification and exploring the social cues/factors that could help communities/individuals identify whether they're at risk of being displaced.
#
# Gentrification is a very contentius issue in New York City especially because it impacts both the quality of life and opportunities for advancement for people who live in NY neighborhoods. Often, established residents who are impacted by gentrification find themselves economically and socially marginalized, and it's alarming that these changes often occur along racial and economic fault lines.
#
#
# **Problem Statement:** Using geographically tagged social media data from Yelp, Foursquare, and Instagram, determine whether or not higher levels of social media are positively associated with the likelihood of a neighborhood in NYC to become gentrified (aka incur higher property values both for renting and purchase options).
#
# **What kind of impact do you think it could have?**
# By having information earlier on about which areas/neighborhoods are most likely to be undergo gentrification, government officials and community groups can begin preparing residents and adjusting policies, such as rent control/stabilization policies, to lessen the negative impacts of gentrification or to ensure that the rights/needs of established residents are better taken into account when development decisions are being made in that area.
#
# Other impacts this analysis could have are actually to promote/induce gentrification (aka identify "hot areas" that should have more investments and that businesses should move to).
#
#
# **Where does this seem to reside as a machine learning problem? Are you predicting some continuous number, or predicting a binary value?**
# While the nature of this project could include predict either a continuous number (predicting home values) or a binary value (Y/N to whether an area is at "risk" of being gentrified), I specifically chose to combine those two outcomes in a way. By trying to predict a "normal" (aka not impacted by gentrification) growth rate for home values, I'll try to identify if the growth rate for the values of properties (both rental and sales) is "normal" or is a high outlier (aka impacted by gentrification).
#
# **What do you think will have the most impact in predicting the value you are interested in solving for?**
# I'm specifically using social media data and also the presence/price of airbnb values to see if those factors impact/point to the likelihood of an area that's likely to undergo gentrification. The timeline of predicting vs. identifying in early stages (aka if an area is also showing these signs, does that mean that gentrification has already begun?)

# %% [markdown]
# ### Datasets
# - Description of data set available, at the field level (see table)
#
# - If from an API, include a sample return (this is usually included in API documentation!) (if doing this in markdown, use the javacription code tag)
#
# (see below in Part 3 for this information)

# %% [markdown]
# ### Domain knowledge
# - What experience do you already have around this area?
# - Does it relate or help inform the project in any way?
# - What other research efforts exist? See what approaches others have made, or talk with your colleagues if it is work related about previous attempts at similar problems.
#
# > http://www.cam.ac.uk/research/news/predicting-gentrification-through-social-networking-data
# > https://www.inverse.com/article/14168-predict-gentrification-through-social-media-data
# > https://spatial.usc.edu/wp-content/uploads/2015/03/Schaefer_Bryan.pdf
# > https://www.npr.org/sections/13.7/2017/08/29/546980178/what-does-it-take-to-see-gentrification-before-it-happens
# > http://mappingideas.sdsu.edu/big-group2016/group4/
# > https://datasmart.ash.harvard.edu/news/article/where-is-gentrification-happening-in-your-city-1055
#
#
# - Include a benchmark, how other models have performed, even if you are unsure what the metric means.

# %% [markdown]
# ### Project Concerns
# - What questions do you have about your project? What are you not sure you quite yet understand? (The more honest you are about this, the easier your instructors can help).
# - What are the assumptions and caveats to the problem?
# - What data do you not have access to but wish you had?
# - What is already implied about the observations in your data set? For example, if your primary data set is twitter data, it may not be representative of the whole sample (say, predicting who would win an election)
# - What are the risks to the project?
# - What's the cost of your model being wrong? (What's the benefit of your model being right?)
# - Is any of the data incorrect? Could it be incorrect?

# %% [markdown]
# ### Outcomes
# - What do you expect the output to look like?
# - What does your target audience expect the output to look like?
# - What gain do you expect from your most important feature on its own?
# - How complicated does your model have to be?
# - How successful does your project have to be in order to be considered a "success"?
# - What will you do if the project is a bust (this happens! but it shouldn't here)?

# %% [markdown]
# **Obtaining data from API:**
# https://schoolofdata.org/2013/11/18/web-apis-for-non-programmers/

# %% [markdown]
# **Data Sets:**
# Social Media Data – “features”
# - Yelp reviews + businesses: https://www.kaggle.com/yelp-dataset/yelp-dataset
# - Foursquare  API: https://developer.foursquare.com/
# - Instagram API: https://www.instagram.com/developer/
#
# **Using Property Value as a Proxy for Gentrification**
# Airbnb Listings: http://insideairbnb.com/get-the-data.html
# Zillow: https://www.zillow.com/research/data/
# Streeteasy: https://streeteasy.com/blog/download-data/
#
#
# Step 1: Get access to the social media APIs from Foursquare and Instagram (the yelp reviews + business data set is already in a ready-format) and confirm that geospatial data is available for all the sources
# Step 2: Do EDA and confirm data quality across all datasets
# Step 3: Determine thresholds for gentrified or not using property value (what does it mean for rent/property value to be out of the norm)
# Step 4: Identify trends in growth (or lack thereof) of social media across NYC and categorize into tiers/groups/ranks
# Step 5: Determine if ranks of social media activity for a given area is predictive of changes in property value
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Helpful link: https://www.dataquest.io/blog/python-api-tutorial/
#
# From Greg: if they don’t have a sdk then you need to make `http` calls in your language of choice - python makes this easy but i always struggle with the authentication pieces - some apis make it more challenging than others.  SDKs will make it more straight forward

# %% [markdown]
# ### Instagram API
# - client ID - d8acf95e75474e0ab970b661c20b3adb
#
# - Client Secret 91664a8e599e42d2a6a824de6ea456ec
#
# https://auth0.com/docs/connections/social/instagram

# %%
import os
os.environ["instagram_client_secret"] = "91664a8e599e42d2a6a824de6ea456ec"

# Set environment variable + check
# export instagram_client_secret=91664a8e599e42d2a6a824de6ea456ec
# echo $instagram_client_secret

# %% [markdown]
# ### Part 3: Project Design Writeup
#
# > From: https://github.com/ga-students/DAT-NYC-1.16.18/tree/master/projects/final-project/03-exploratory-analysis
#
# **Requirements:**
# - Review the data set and project with an EIR during office hours.
# - Practice importing (potentially unformatted) data into clean matrices|data frames, and if necessary, export into a form that makes sense (text files or a database, for example).
# - Explore the mathematical properties and visualize data through a python visualization tool (matplotlib and seaborn)
# - Provide insight about the data set and any impact on a hypothesis.
#
# **Detailed Breakdown:**
# - A well organized iPython notebook with code and output
# - At least one visual for each independent variable and, if possible, its relationship to your dependent variable.
# - It's just as important to show what's not correlated as it is to show any actual correlations found.
# - Visuals should be well labeled and intuitive based on the data types.
#
# **Bonus:**
# - Surface and share your analysis online. Jupyter makes this very simple and the setup should not take long.
# - Try experimenting with other visualization languages; python/pandas-highcharts, shiny/r, or for a real challenge, d3 on its own. Interactive data analysis opens the doors for others to easily interpret your work and explore the data themselves!

# %% [markdown]
# ### Predicting house prices using python
#
# https://towardsdatascience.com/create-a-model-to-predict-house-prices-using-python-d34fe8fad88f
# > https://github.com/Shreyas3108/house-price-prediction

# %% [markdown]
# # Airbnb Listings: http://insideairbnb.com/get-the-data.html
#
# - listing
# - calendar data (October 2017)
# > Data goes from 2017 back to January 2015
# - neighborhoods

# %%
import pandas as pd

# %%
neighborhoods = pd.read_csv('../final_project/neighborhoods.csv')
neighborhoods.head()
# Out:
#   neighbourhood_group neighbourhood
# 0               Bronx      Allerton
# 1               Bronx    Baychester
# 2               Bronx       Belmont
# 3               Bronx     Bronxdale
# 4               Bronx   Castle Hill

# %%
listings = pd.read_csv('../final_project/listings.csv')
listings.head()
# Out:
#          id                                            name   host_id  \
# 0  18461891  Bright, comfortable 1B studio near everything!    916092
# 1  20702398                      Quiet house on City Island   1457680
# 2   6627449                  Large 1 BDRM in Great location  13886510
# 3  19949243                         Stay aboard  a sailboat   1149260
# 4   1886820                  Quaint City Island Community.    9815788
#
#     host_name neighbourhood_group     neighbourhood   latitude  longitude  \
# 0  Connie Mae              Queens  Ditmars Steinway  40.774142 -73.916246
# 1       James               Bronx       City Island  40.849191 -73.786509
# 2      Arlene               Bronx       City Island  40.849775 -73.786609
# 3        MoMo               Bronx       City Island  40.848838 -73.782276
# 4       Steve               Bronx       City Island  40.841144 -73.783052
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    110               6                  0         NaN
# 1     Private room     50               1                  2  2017-10-01
# 2  Entire home/apt    125               3                 21  2017-09-26
# 3  Entire home/apt    100               3                  0         NaN
# 4  Entire home/apt    300               7                  0         NaN
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0                NaN                               1                 0
# 1               2.00                               1               169
# 2               0.77                               1               363
# 3                NaN                               1                90
# 4                NaN                               1               365

# %%
listings = pd.read_csv('../final_project/listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
print(listings)
# Out:
#           id                            listing_url       scrape_id  \
# 0   18461891  https://www.airbnb.com/rooms/18461891  20171002002103
# 1   20702398  https://www.airbnb.com/rooms/20702398  20171002002103
# 2    6627449   https://www.airbnb.com/rooms/6627449  20171002002103
# 3   19949243  https://www.airbnb.com/rooms/19949243  20171002002103
# 4    1886820   https://www.airbnb.com/rooms/1886820  20171002002103
# 5    5557381   https://www.airbnb.com/rooms/5557381  20171002002103
# 6   19609887  https://www.airbnb.com/rooms/19609887  20171002002103
# 7    7949480   https://www.airbnb.com/rooms/7949480  20171002002103
# 8   21057372  https://www.airbnb.com/rooms/21057372  20171002002103
# 9   16042478  https://www.airbnb.com/rooms/16042478  20171002002103
# 10   9147025   https://www.airbnb.com/rooms/9147025  20171002002103
# 11   1936633   https://www.airbnb.com/rooms/1936633  20171002002103
# 12  19758402  https://www.airbnb.com/rooms/19758402  20171002002103
# 13  11675715  https://www.airbnb.com/rooms/11675715  20171002002103
# 14   3400359   https://www.airbnb.com/rooms/3400359  20171002002103
# 15   4407790   https://www.airbnb.com/rooms/4407790  20171002002103
# 16    715270    https://www.airbnb.com/rooms/715270  20171002002103
# 17  18852048  https://www.airbnb.com/rooms/18852048  20171002002103
# 18    759901    https://www.airbnb.com/rooms/759901  20171002002103
# 19  13864221  https://www.airbnb.com/rooms/13864221  20171002002103
# 20  12496118  https://www.airbnb.com/rooms/12496118  20171002002103
# 21  13109017  https://www.airbnb.com/rooms/13109017  20171002002103
# 22   9513511   https://www.airbnb.com/rooms/9513511  20171002002103
# 23  19174868  https://www.airbnb.com/rooms/19174868  20171002002103
# 24  10801360  https://www.airbnb.com/rooms/10801360  20171002002103
# 25   8294259   https://www.airbnb.com/rooms/8294259  20171002002103
# 26    182177    https://www.airbnb.com/rooms/182177  20171002002103
# 27  17876530  https://www.airbnb.com/rooms/17876530  20171002002103
# 28   5046189   https://www.airbnb.com/rooms/5046189  20171002002103
# 29    773041    https://www.airbnb.com/rooms/773041  20171002002103
# ..       ...                                    ...             ...
# 70  11192104  https://www.airbnb.com/rooms/11192104  20171002002103
# 71  12956315  https://www.airbnb.com/rooms/12956315  20171002002103
# 72  17234796  https://www.airbnb.com/rooms/17234796  20171002002103
# 73    764052    https://www.airbnb.com/rooms/764052  20171002002103
# 74   4357134   https://www.airbnb.com/rooms/4357134  20171002002103
# 75  12972200  https://www.airbnb.com/rooms/12972200  20171002002103
# 76   3250448   https://www.airbnb.com/rooms/3250448  20171002002103
# 77   8365172   https://www.airbnb.com/rooms/8365172  20171002002103
# 78  21093522  https://www.airbnb.com/rooms/21093522  20171002002103
# 79   1046443   https://www.airbnb.com/rooms/1046443  20171002002103
# 80   6480685   https://www.airbnb.com/rooms/6480685  20171002002103
# 81  19979903  https://www.airbnb.com/rooms/19979903  20171002002103
# 82  11625684  https://www.airbnb.com/rooms/11625684  20171002002103
# 83  20689638  https://www.airbnb.com/rooms/20689638  20171002002103
# 84  11641041  https://www.airbnb.com/rooms/11641041  20171002002103
# 85  18159825  https://www.airbnb.com/rooms/18159825  20171002002103
# 86  15530531  https://www.airbnb.com/rooms/15530531  20171002002103
# 87   7927466   https://www.airbnb.com/rooms/7927466  20171002002103
# 88   8741446   https://www.airbnb.com/rooms/8741446  20171002002103
# 89  19875244  https://www.airbnb.com/rooms/19875244  20171002002103
# 90    239733    https://www.airbnb.com/rooms/239733  20171002002103
# 91  10735397  https://www.airbnb.com/rooms/10735397  20171002002103
# 92  10789911  https://www.airbnb.com/rooms/10789911  20171002002103
# 93  15336336  https://www.airbnb.com/rooms/15336336  20171002002103
# 94   8783113   https://www.airbnb.com/rooms/8783113  20171002002103
# 95   6950074   https://www.airbnb.com/rooms/6950074  20171002002103
# 96  13512004  https://www.airbnb.com/rooms/13512004  20171002002103
# 97  20459144  https://www.airbnb.com/rooms/20459144  20171002002103
# 98   2896760   https://www.airbnb.com/rooms/2896760  20171002002103
# 99   6043315   https://www.airbnb.com/rooms/6043315  20171002002103
#
#    last_scraped                                               name  \
# 0    2017-10-03     Bright, comfortable 1B studio near everything!
# 1    2017-10-03                         Quiet house on City Island
# 2    2017-10-03                     Large 1 BDRM in Great location
# 3    2017-10-03                            Stay aboard  a sailboat
# 4    2017-10-03                     Quaint City Island Community.
# 5    2017-10-03                            Quaint City Island Home
# 6    2017-10-02                                      Sweet Getaway
# 7    2017-10-03  City Island Sanctuary BR & Private Bath w Parking
# 8    2017-10-03                     Relax and unwind on the water.
# 9    2017-10-03                        WATERFRONT STUDIO APARTMENT
# 10   2017-10-03                           Cozy City Island Cottage
# 11   2017-10-03                Great 1BD waterfront City Island NY
# 12   2017-10-03  Autumn getaway -House near beach & woodland tr...
# 13   2017-10-02                       Cozy 1 BR Basement Apartment
# 14   2017-10-03                                   Awesome Deal NYC
# 15   2017-10-02                                       Retreat Room
# 16   2017-10-03  2 Beds/Queen & Full Beautiful Room 40 minsT.Sq...
# 17   2017-10-03      Clean, spacious and comfortable room at Bronx
# 18   2017-10-03                  GREAT PRICE for GREAT GUESTS ONLY
# 19   2017-10-03                     Live, Love, Stay in the Bronx!
# 20   2017-10-03                      Entire Home in NYC- 1 bedroom
# 21   2017-10-02                        Large Private Room! w. Lock
# 22   2017-10-02               Beautiful, spacious & sunny bedroom!
# 23   2017-10-03                     Bronx Apartment for travellers
# 24   2017-10-03                    Studio near BX Botanical Garden
# 25   2017-10-03  Room in Private House(Queen Bed) by Montefiore...
# 26   2017-10-03                PRIVATE FLAT / APARTMENT- $SPECIAL$
# 27   2017-10-03                          Spacious Garden Apartment
# 28   2017-10-03                                        Bellissima!
# 29   2017-10-03                   Nice beautiful room In the Bronx
# ..          ...                                                ...
# 70   2017-10-03                Charming Cozy Master Room @ Ditmars
# 71   2017-10-03    Room in 2BR Astoria apt (20min to Central Park)
# 72   2017-10-03     Astoria 2BR in Quiet Corner Close to Manhattan
# 73   2017-10-03                 1 Bedroom Apartment in quiet area.
# 74   2017-10-02                                   Beautiful NY Gem
# 75   2017-10-03                                The best of Astoria
# 76   2017-10-03           Clean and Modern Apartment in Calm Area.
# 77   2017-10-03                BEST Location in Heart of Astoria!!
# 78   2017-10-03                                    THE GARDEN ROOM
# 79   2017-10-03  Beautiful & spacious apartment in Astoria, Queens
# 80   2017-10-03                Cozy,  single bed room.15min to NYC
# 81   2017-10-03   Jolly Bedroom! 3 minute walk to Astoria Ditmars!
# 82   2017-10-03                 Astoria Suite - 20min to Manhattan
# 83   2017-10-03              LARGE PRIVATE ROOM CLOSE TO MANHATTAN
# 84   2017-10-03           3 Bedrooms - Spacious & Close to Subway!
# 85   2017-10-02                            Astoria's simple studio
# 86   2017-10-03  Apartment in Heart of Astoria Step to the Trai...
# 87   2017-10-03                 A Little Apple Tree House, Astoria
# 88   2017-10-02                   Clean, inviting apt.15min to NYC
# 89   2017-10-03                         Spacious and quiet bedroom
# 90   2017-10-03                               Astoria Garden Suite
# 91   2017-10-03                      Modern Two bedroom in Astoria
# 92   2017-10-03                             One Bedroom in Astoria
# 93   2017-10-02                Clean, Bright 1BD in Trendy Astoria
# 94   2017-10-02                      COZY near the Big City Room 1
# 95   2017-10-03                          Beautiful, Cozy Apartment
# 96   2017-10-02         Big and bright bedroom in Astoria, Queens!
# 97   2017-10-02       Spacious, Sunny room in the heart of Astoria
# 98   2017-10-02                        Safe, cozy & minutes to NYC
# 99   2017-10-02                   Cozy Private Red Room in Astoria
#
#                                               summary  \
# 0   *Looking to fill these specific dates: June 24...
# 1   1 private bedroom and bathroom available for o...
# 2   This ground floor apartment is light and airy ...
# 3                              stay aboard a sailboat
# 4   Quiet island  boating town on Long Island Soun...
# 5   Located in an old sea-shanty town, our home ha...
# 6   Getaway for two (2) or up to seven (7), nice s...
# 7   Relax on City Island in our quiet guest room w...
# 8   On City Island step away from all City Island ...
# 9   My place is close to Sea Shore. You’ll love my...
# 10  City Island is a small community at the edge o...
# 11                                                NaN
# 12  City Island is a quaint coastal town located 4...
# 13  City Island is an active, year-round nautical ...
# 14  Beautiful, cozy  and comfortable room in a wel...
# 15  A cool and comfortable room to retreat in at t...
# 16  Located in one of the safest Bronx neighborhoo...
# 17  BRIGHT PRIVATE BEDROOM avail June 25th in Bron...
# 18  Private room in our parent's 3 BR house, with ...
# 19  If you're looking for a place in NYC without p...
# 20  Entire Apartment with a comfy Queen size bed f...
# 21  Great atmosphere - Privacy - Convenient - Heal...
# 22  This charming pre-war apartment building is lo...
# 23  Access to the 2 and 5 train to Manhattan. Chea...
# 24  Studio conveniently located near the original ...
# 25  Private room with a comfy Queen size bed for o...
# 26  1st Floor 1 Bedroom Flat/Apartment incl Kitche...
# 27  Entire Spacious Garden level apartment with a ...
# 28  IN THE HEART OF THE GREAT ITALIAN NEIGHBORHOOD...
# 29  It is a nice room with a queen and  and twin s...
# ..                                                ...
# 70  A cozy master bedroom in a large 2BR apartment...
# 71  I'm renting a room in a 2BR recently renovated...
# 72  Astoria apartment in quiet neighborhood close ...
# 73  Perfect for the holidays in NYC. Renting out m...
# 74  This is the perfect place for you and your fam...
# 75  My place is close to Starbucks, MP Taverna, As...
# 76  The Apartment  Reviews speak by itself : There...
# 77  Come stay at my beautiful place in Astoria (on...
# 78  Room with private entrance-heart of Astoria 17...
# 79  5 mins from LGA (very SUITABLE for layovers!) ...
# 80  Comfortable & roomy;sweetly decorated &welcomi...
# 81  Welcome to Astoria! It is one of New York City...
# 82  7-10 min walk to subway (N/Q) trains Nice, com...
# 83  Recently restored/ renovated Victorian house. ...
# 84  Large, modern, 3 bedroom in one of NYC's most ...
# 85  Astoria is a very diverse community. Astoria i...
# 86  My place is close to Taverna Kyclades, MP Tave...
# 87  Lovely apartment in Astoria. 2 bedroom apartme...
# 88  Tastefully decorated & located in a top Astori...
# 89  It's a renovated apartment spacious and light ...
# 90  Staying at the north end of Astoria - Ditmars ...
# 91  This modern two-bedroom with huge living room ...
# 92  Our place is a 7 minute walk to the N/Q train ...
# 93  This bright, clean and spacious apartment is l...
# 94  Great neighborhood, very quiet and peaceful. A...
# 95  Beautiful and cozy apartment.  Very clean, wit...
# 96  Welcome to our spare bedroom!  You’ll love it ...
# 97  This is a cute, pre-war apartment in the middl...
# 98  An inviting private bedroom located in a beaut...
# 99  Private room with harwood floors in newly reno...
#
#                                                 space  \
# 0   Very well illuminated space includes comfortab...
# 1                                                 NaN
# 2   We are close to fishing, boating, biking, hors...
# 3                                                 NaN
# 4    Master bed with queen bed, full bath and offi...
# 5   You won't find a place so close to the city (N...
# 6   $150 first  two guests per night, $25 each add...
# 7   On parle français et anglais, (lire le françai...
# 8                                                 NaN
# 9                                        (URL HIDDEN)
# 10  This cozy little cottage is an open floor plan...
# 11  I am renting my lovely one bedroom apartment t...
# 12  Three bedroom house. Queen, twin and empty roo...
# 13  This very cozy apartment with features a queen...
# 14  Room is on the second floor of the house. Our ...
# 15  Welcome to our home! This is the clean, privat...
# 16  Located in one of the safest Bronx neighborhoo...
# 17                                                NaN
# 18  WELCOME TO THE BRONX as featured on CNN's Anth...
# 19                        2nd floor, private entrance
# 20  ***** Please provide the purpose of your trip,...
# 21  So this very big room is completely separated ...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  WELCOME TO THE BRONX as featured on CNN's Anth...
# 27  **** Please provide the purpose of your trip, ...
# 28  NO OTHER LISTING IN NYC LIKE THIS . YOUR OWN H...
# 29  Located in one of the safest Bronx neighborhoo...
# ..                                                ...
# 70                                                NaN
# 71  Renovated kitchen with a dishwasher, coffee pr...
# 72                                                NaN
# 73  Renting out my apartment while I'm gone for th...
# 74                                                NaN
# 75  This beautiful large two bedrooms apartment is...
# 76  Extra clean apartment brand new furniture best...
# 77  Astoria is one of the safest neighborhood is a...
# 78                                                NaN
# 79  This is a huge 1-bdr apartment with a bathroom...
# 80  Inviting & clean. Large closet. Desk to work o...
# 81  The apartment is our happy place. Three if us ...
# 82  It is a nice and large space with separate bed...
# 83  This is a large private room, with everything ...
# 84  ~ Very spacious 3 bedroom apartment. 2 queen b...
# 85  Your getting the studio level of this house fo...
# 86                                                NaN
# 87                                                NaN
# 88  An apartment that is clean and kept with a lot...
# 89  The apartment it's clean quiet very close to t...
# 90  (Description en Espanol hacia abajo.) Staying ...
# 91  This space was recently renovated to bring it ...
# 92                                                NaN
# 93  You'll have private access to the entire top f...
# 94  Consider this your 2nd home, an amazing place ...
# 95  We have a wonderful, clean, newly renovated ap...
# 96                                                NaN
# 97                                                NaN
# 98  This apartment is your home away from home!! F...
# 99  Private House with huge parking space up to 8 ...
#
#                                           description experiences_offered  \
# 0   *Looking to fill these specific dates: June 24...                none
# 1   1 private bedroom and bathroom available for o...                none
# 2   This ground floor apartment is light and airy ...                none
# 3                              stay aboard a sailboat                none
# 4   Quiet island  boating town on Long Island Soun...                none
# 5   Located in an old sea-shanty town, our home ha...                none
# 6   Getaway for two (2) or up to seven (7), nice s...                none
# 7   Relax on City Island in our quiet guest room w...                none
# 8   On City Island step away from all City Island ...                none
# 9   My place is close to Sea Shore. You’ll love my...                none
# 10  City Island is a small community at the edge o...                none
# 11  I am renting my lovely one bedroom apartment t...                none
# 12  City Island is a quaint coastal town located 4...                none
# 13  City Island is an active, year-round nautical ...                none
# 14  Beautiful, cozy  and comfortable room in a wel...                none
# 15  A cool and comfortable room to retreat in at t...                none
# 16  Located in one of the safest Bronx neighborhoo...                none
# 17  BRIGHT PRIVATE BEDROOM avail June 25th in Bron...                none
# 18  Private room in our parent's 3 BR house, with ...                none
# 19  If you're looking for a place in NYC without p...                none
# 20  Entire Apartment with a comfy Queen size bed f...                none
# 21  Great atmosphere - Privacy - Convenient - Heal...                none
# 22  This charming pre-war apartment building is lo...                none
# 23  Access to the 2 and 5 train to Manhattan. Chea...                none
# 24  Studio conveniently located near the original ...                none
# 25  Private room with a comfy Queen size bed for o...                none
# 26  1st Floor 1 Bedroom Flat/Apartment incl Kitche...                none
# 27  Entire Spacious Garden level apartment with a ...                none
# 28  IN THE HEART OF THE GREAT ITALIAN NEIGHBORHOOD...                none
# 29  It is a nice room with a queen and  and twin s...                none
# ..                                                ...                 ...
# 70  A cozy master bedroom in a large 2BR apartment...                none
# 71  I'm renting a room in a 2BR recently renovated...                none
# 72  Astoria apartment in quiet neighborhood close ...                none
# 73  Perfect for the holidays in NYC. Renting out m...                none
# 74  This is the perfect place for you and your fam...                none
# 75  My place is close to Starbucks, MP Taverna, As...                none
# 76  The Apartment  Reviews speak by itself : There...                none
# 77  Come stay at my beautiful place in Astoria (on...                none
# 78  Room with private entrance-heart of Astoria 17...                none
# 79  5 mins from LGA (very SUITABLE for layovers!) ...                none
# 80  Comfortable & roomy;sweetly decorated &welcomi...                none
# 81  Welcome to Astoria! It is one of New York City...                none
# 82  7-10 min walk to subway (N/Q) trains Nice, com...                none
# 83  Recently restored/ renovated Victorian house. ...                none
# 84  Large, modern, 3 bedroom in one of NYC's most ...                none
# 85  Astoria is a very diverse community. Astoria i...                none
# 86  My place is close to Taverna Kyclades, MP Tave...                none
# 87  Lovely apartment in Astoria. 2 bedroom apartme...                none
# 88  Tastefully decorated & located in a top Astori...                none
# 89  It's a renovated apartment spacious and light ...                none
# 90  Staying at the north end of Astoria - Ditmars ...                none
# 91  This modern two-bedroom with huge living room ...                none
# 92  Our place is a 7 minute walk to the N/Q train ...                none
# 93  This bright, clean and spacious apartment is l...                none
# 94  Great neighborhood, very quiet and peaceful. A...                none
# 95  Beautiful and cozy apartment.  Very clean, wit...                none
# 96  Welcome to our spare bedroom!  You’ll love it ...                none
# 97  This is a cute, pre-war apartment in the middl...                none
# 98  An inviting private bedroom located in a beaut...                none
# 99  Private room with harwood floors in newly reno...                none
#
#                                 neighborhood_overview        ...          \
# 0   There are Michelin-rated restaurants in the ar...        ...
# 1   This neighborhood is dope! Lot's of seafood re...        ...
# 2   City Island is a unique and a hidden gem of Ne...        ...
# 3                                                 NaN        ...
# 4    Small New England type town in the middle of ...        ...
# 5   City Island is unique in two ways. First, you ...        ...
# 6   If you enjoy seafood, City Island is the place...        ...
# 7   City Island is a unique sanctuary in New York ...        ...
# 8                                                 NaN        ...
# 9                                        (URL HIDDEN)        ...
# 10  City Island is famous for it's seafood restaur...        ...
# 11  The place is very conveniently located in City...        ...
# 12  Beautiful East Coast nature setting. Walk/bike...        ...
# 13  City Island is a small island and a neighborho...        ...
# 14  Our home  is conveniently located in the North...        ...
# 15  Great neighborhood, safe, clean, peaceful. Nea...        ...
# 16                                                NaN        ...
# 17                                                NaN        ...
# 18  Get situated right in the heart of the beautif...        ...
# 19     Access to Manhattan. Neighborhood charm. Safe!        ...
# 20  It's a quiet, safe tree-lined neighborhood (Gr...        ...
# 21  The community is beautiful and peaceful. There...        ...
# 22  This lovely LARGE 3 bedroom apartment is just ...        ...
# 23                                                NaN        ...
# 24                                                NaN        ...
# 25  It's a quiet, safe tree-lined neighborhood (Gr...        ...
# 26  Situated right in the heart of the Bronx where...        ...
# 27  It's a quiet, safe tree-lined neighborhood (Gr...        ...
# 28  IN THE HEART OF THE GREAT ITALIAN NEIGHBORHOOD...        ...
# 29                                                NaN        ...
# ..                                                ...        ...
# 70                                                NaN        ...
# 71  Known for its delicious Greek food and great b...        ...
# 72                                                NaN        ...
# 73  Quiet tree lined street of houses. Near a beau...        ...
# 74                                                NaN        ...
# 75                                                NaN        ...
# 76  Astoria, New York, is known for its art galler...        ...
# 77  Astoria is one of the safest neighborhood is a...        ...
# 78                                                NaN        ...
# 79  Astoria is the hub of both the young and the b...        ...
# 80  Centrally located to all that Astoria has to o...        ...
# 81  Astoria is the best. It is one of the most div...        ...
# 82  Many good restaurants & Bars around Very safe ...        ...
# 83  Located conveniently near the N/W train line a...        ...
# 84  Astoria, Queens, is one of the most unique nei...        ...
# 85  Welcome to the heart of Astoria. Quiet and pri...        ...
# 86                                                NaN        ...
# 87                                                NaN        ...
# 88  Astoria is known, world-wide, for its safety, ...        ...
# 89  It's close to N and W train supermarket coffe ...        ...
# 90  English: Very safe and active near the train s...        ...
# 91  Astoria is a vibrant neighborhood the uniquene...        ...
# 92                                                NaN        ...
# 93  Astoria is one of the hippest neighborhoods in...        ...
# 94  The neighborhood is extremely friendly and ver...        ...
# 95  Our neighboorhood is incredible!  We have a TO...        ...
# 96                                                NaN        ...
# 97                                                NaN        ...
# 98  Astoria is an amazing neighborhood that is ext...        ...
# 99  One of the safest neighborhood in New York Cit...        ...
#
#    requires_license license jurisdiction_names instant_bookable  \
# 0                 f     NaN                NaN                f
# 1                 f     NaN                NaN                f
# 2                 f     NaN                NaN                f
# 3                 f     NaN                NaN                t
# 4                 f     NaN                NaN                f
# 5                 f     NaN                NaN                t
# 6                 f     NaN                NaN                f
# 7                 f     NaN                NaN                f
# 8                 f     NaN                NaN                t
# 9                 f     NaN                NaN                t
# 10                f     NaN                NaN                f
# 11                f     NaN                NaN                t
# 12                f     NaN                NaN                f
# 13                f     NaN                NaN                t
# 14                f     NaN                NaN                t
# 15                f     NaN                NaN                t
# 16                f     NaN                NaN                f
# 17                f     NaN                NaN                t
# 18                f     NaN                NaN                f
# 19                f     NaN                NaN                f
# 20                f     NaN                NaN                f
# 21                f     NaN                NaN                f
# 22                f     NaN                NaN                f
# 23                f     NaN                NaN                f
# 24                f     NaN                NaN                f
# 25                f     NaN                NaN                f
# 26                f     NaN                NaN                t
# 27                f     NaN                NaN                f
# 28                f     NaN                NaN                f
# 29                f     NaN                NaN                t
# ..              ...     ...                ...              ...
# 70                f     NaN                NaN                f
# 71                f     NaN                NaN                f
# 72                f     NaN                NaN                t
# 73                f     NaN                NaN                f
# 74                f     NaN                NaN                f
# 75                f     NaN                NaN                f
# 76                f     NaN                NaN                f
# 77                f     NaN                NaN                t
# 78                f     NaN                NaN                t
# 79                f     NaN                NaN                f
# 80                f     NaN                NaN                f
# 81                f     NaN                NaN                f
# 82                f     NaN                NaN                f
# 83                f     NaN                NaN                f
# 84                f     NaN                NaN                t
# 85                f     NaN                NaN                f
# 86                f     NaN                NaN                t
# 87                f     NaN                NaN                f
# 88                f     NaN                NaN                f
# 89                f     NaN                NaN                t
# 90                f     NaN                NaN                f
# 91                f     NaN                NaN                f
# 92                f     NaN                NaN                f
# 93                f     NaN                NaN                t
# 94                f     NaN                NaN                f
# 95                f     NaN                NaN                f
# 96                f     NaN                NaN                f
# 97                f     NaN                NaN                f
# 98                f     NaN                NaN                t
# 99                f     NaN                NaN                f
#
#    is_business_travel_ready cancellation_policy require_guest_profile_picture  \
# 0                         f              strict                             f
# 1                         f            moderate                             f
# 2                         f              strict                             f
# 3                         f              strict                             f
# 4                         f              strict                             f
# 5                         f            moderate                             f
# 6                         f            flexible                             f
# 7                         f            moderate                             t
# 8                         f              strict                             f
# 9                         f            flexible                             f
# 10                        t            moderate                             f
# 11                        f              strict                             f
# 12                        f            moderate                             f
# 13                        t            flexible                             f
# 14                        f              strict                             f
# 15                        f            moderate                             f
# 16                        f              strict                             f
# 17                        f            flexible                             f
# 18                        f              strict                             t
# 19                        f              strict                             f
# 20                        t              strict                             f
# 21                        f              strict                             f
# 22                        f              strict                             f
# 23                        f            flexible                             f
# 24                        f            flexible                             f
# 25                        f            moderate                             f
# 26                        f              strict                             t
# 27                        f              strict                             f
# 28                        f              strict                             f
# 29                        f              strict                             f
# ..                      ...                 ...                           ...
# 70                        f            flexible                             f
# 71                        f            flexible                             f
# 72                        f            flexible                             f
# 73                        f            flexible                             f
# 74                        f            flexible                             f
# 75                        t              strict                             f
# 76                        f              strict                             f
# 77                        f              strict                             f
# 78                        f              strict                             f
# 79                        f            moderate                             f
# 80                        f              strict                             f
# 81                        f            moderate                             f
# 82                        f            moderate                             f
# 83                        f              strict                             f
# 84                        t              strict                             f
# 85                        t              strict                             f
# 86                        f              strict                             f
# 87                        f              strict                             f
# 88                        f              strict                             f
# 89                        f            flexible                             f
# 90                        t              strict                             f
# 91                        t              strict                             f
# 92                        f            flexible                             f
# 93                        f            moderate                             f
# 94                        f              strict                             f
# 95                        f            moderate                             f
# 96                        f            flexible                             f
# 97                        f            moderate                             f
# 98                        f              strict                             f
# 99                        f              strict                             f
#
#    require_guest_phone_verification calculated_host_listings_count  \
# 0                                 f                              1
# 1                                 f                              1
# 2                                 f                              1
# 3                                 f                              1
# 4                                 f                              1
# 5                                 f                              1
# 6                                 f                              1
# 7                                 t                              1
# 8                                 f                              1
# 9                                 f                              1
# 10                                f                              1
# 11                                f                              1
# 12                                f                              1
# 13                                f                              1
# 14                                f                              4
# 15                                f                              4
# 16                                f                              5
# 17                                f                              1
# 18                                t                              4
# 19                                f                              1
# 20                                f                              3
# 21                                f                              1
# 22                                f                              1
# 23                                f                              1
# 24                                f                              2
# 25                                f                              3
# 26                                t                              4
# 27                                f                              3
# 28                                f                              3
# 29                                f                              5
# ..                              ...                            ...
# 70                                f                              2
# 71                                f                              1
# 72                                f                              1
# 73                                f                              1
# 74                                f                              1
# 75                                f                              2
# 76                                f                              1
# 77                                f                              1
# 78                                f                              1
# 79                                f                              2
# 80                                f                              8
# 81                                f                              1
# 82                                f                              6
# 83                                f                              8
# 84                                f                              2
# 85                                f                              1
# 86                                f                              1
# 87                                f                              1
# 88                                f                              8
# 89                                f                              1
# 90                                f                              1
# 91                                f                              1
# 92                                f                              1
# 93                                f                              1
# 94                                f                              2
# 95                                f                              1
# 96                                f                              2
# 97                                f                              1
# 98                                f                              4
# 99                                f                              2
#
#     reviews_per_month
# 0                 NaN
# 1                2.00
# 2                0.77
# 3                 NaN
# 4                 NaN
# 5                3.27
# 6                1.58
# 7                1.49
# 8                 NaN
# 9                 NaN
# 10               2.78
# 11               1.09
# 12               3.70
# 13               5.88
# 14               1.82
# 15               0.98
# 16               2.17
# 17               0.24
# 18               0.56
# 19               0.36
# 20               1.56
# 21               0.56
# 22               0.33
# 23                NaN
# 24               0.08
# 25               0.93
# 26               3.02
# 27               3.73
# 28               1.19
# 29               1.59
# ..                ...
# 70                NaN
# 71                NaN
# 72               0.26
# 73               0.11
# 74                NaN
# 75               0.21
# 76               3.42
# 77               4.79
# 78                NaN
# 79               3.64
# 80               0.63
# 81               0.67
# 82               3.11
# 83               2.73
# 84               3.58
# 85               3.68
# 86               0.79
# 87               1.47
# 88               1.64
# 89               5.45
# 90               0.57
# 91               0.89
# 92               0.09
# 93               2.05
# 94               0.21
# 95               0.45
# 96               0.38
# 97               2.86
# 98               2.33
# 99               6.66
#
# [100 rows x 96 columns]

# %% [markdown]
# ## Instagram: https://www.instagram.com/developer/authentication/

# %% [markdown]
# ### Foursquare Places API:  https://developer.foursquare.com/docs/api/getting-started

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
  client_id="1KNECHOW4ALXKWS4OWU2TEUZMPW0WUN1NORS2OUMWWBBCV4C",
  client_secret='O4QOOLKGDZK44DTBRPQIUDGO2Z4XQYYJQOJ0LN5E5FAQASMM',
  v='20170801',
  ll='40.7243,-74.0018',
  query='coffee',
  limit=1
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %% [markdown]
# ### Client ID
# 1KNECHOW4ALXKWS4OWU2TEUZMPW0WUN1NORS2OUMWWBBCV4C
# ### Client Secret
# O4QOOLKGDZK44DTBRPQIUDGO2Z4XQYYJQOJ0LN5E5FAQASMM

# %%
data
# Out:
# {u'meta': {u'code': 200, u'requestId': u'5a95c5e1db04f53652c3c3be'},
#  u'response': {u'groups': [{u'items': [{u'reasons': {u'count': 0,
#        u'items': [{u'reasonName': u'globalInteractionReason',
#          u'summary': u'This spot is popular',
#          u'type': u'general'}]},
#       u'referralId': u'e-0-45e98bacf964a52080431fe3-0',
#       u'tips': [{u'agreeCount': 3,
#         u'canonicalUrl': u'https://foursquare.com/item/54e51f11498ef4039fd5157a',
#         u'createdAt': 1424301841,
#         u'disagreeCount': 0,
#         u'id': u'54e51f11498ef4039fd5157a',
#         u'likes': {u'count': 3, u'groups': [], u'summary': u'3 likes'},
#         u'logView': True,
#         u'photo': {u'createdAt': 1424301843,
#          u'height': 1440,
#          u'id': u'54e51f13498ecf2f32fbfb2e',
#          u'prefix': u'https://igx.4sqi.net/img/general/',
#          u'source': {u'name': u'Foursquare for iOS',
#           u'url': u'https://foursquare.com/download/#/iphone'},
#          u'suffix': u'/54904394_O0ODgxCxgXgr6Mf8Odchhs1ZExvaCLIy0zXXsV6fiIc.jpg',
#          u'visibility': u'public',
#          u'width': 1920},
#         u'photourl': u'https://igx.4sqi.net/img/general/original/54904394_O0ODgxCxgXgr6Mf8Odchhs1ZExvaCLIy0zXXsV6fiIc.jpg',
#         u'text': u"Very good service!!! Friendly 'barista' lovely hot chocolat drinks en lemon merengue tart. Lovely place!!!!",
#         u'todo': {u'count': 0},
#         u'type': u'user',
#         u'user': {u'firstName': u'Irinka',
#          u'gender': u'female',
#          u'id': u'54904394',
#          u'photo': {u'prefix': u'https://igx.4sqi.net/img/user/',
#           u'suffix': u'/54904394-DEQJDWCKPRFTLJDE.jpg'}}}],
#       u'venue': {u'allowMenuUrlEdit': True,
#        u'beenHere': {u'count': 0,
#         u'lastCheckinExpiredAt': 0,
#         u'marked': False},
#        u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           u'suffix': u'.png'},
#          u'id': u'4bf58dd8d48988d1d0941735',
#          u'name': u'Dessert Shop',
#          u'pluralName': u'Dessert Shops',
#          u'primary': True,
#          u'shortName': u'Desserts'}],
#        u'contact': {u'facebook': u'105916566143389',
#         u'facebookName': u'MarieBelle',
#         u'facebookUsername': u'mariebellenewyork',
#         u'formattedPhone': u'(212) 925-6999',
#         u'phone': u'2129256999',
#         u'twitter': u'mariebelleny'},
#        u'delivery': {u'id': u'488596',
#         u'provider': {u'icon': {u'name': u'/delivery_provider_seamless_20180129.png',
#           u'prefix': u'https://igx.4sqi.net/img/general/cap/',
#           u'sizes': [40, 50]},
#          u'name': u'seamless'},
#         u'url': u'https://www.seamless.com/menu/marie-belle-new-york-484-broome-st-new-york/488596?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=488596'},
#        u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#        u'hours': {u'isLocalHoliday': False,
#         u'isOpen': True,
#         u'richStatus': {u'entities': [], u'text': u'Open until 7:00 PM'},
#         u'status': u'Open until 7:00 PM'},
#        u'id': u'45e98bacf964a52080431fe3',
#        u'location': {u'address': u'484 Broome St',
#         u'cc': u'US',
#         u'city': u'New York',
#         u'country': u'United States',
#         u'crossStreet': u'btwn W Broadway & Wooster St',
#         u'distance': 145,
#         u'formattedAddress': [u'484 Broome St (btwn W Broadway & Wooster St)',
#          u'New York, NY 10013',
#          u'United States'],
#         u'labeledLatLngs': [{u'label': u'display',
#           u'lat': 40.72310132633388,
#           u'lng': -74.00247749675871}],
#         u'lat': 40.72310132633388,
#         u'lng': -74.00247749675871,
#         u'postalCode': u'10013',
#         u'state': u'NY'},
#        u'name': u'MarieBelle',
#        u'photos': {u'count': 0, u'groups': []},
#        u'price': {u'currency': u'$', u'message': u'Moderate', u'tier': 2},
#        u'rating': 9.3,
#        u'ratingColor': u'00B551',
#        u'ratingSignals': 260,
#        u'stats': {u'checkinsCount': 3053,
#         u'tipCount': 84,
#         u'usersCount': 2501},
#        u'url': u'http://mariebelle.com',
#        u'venuePage': {u'id': u'81170724'},
#        u'verified': True}}],
#     u'name': u'recommended',
#     u'type': u'Recommended Places'}],
#   u'headerFullLocation': u'SoHo, New York',
#   u'headerLocation': u'SoHo',
#   u'headerLocationGranularity': u'neighborhood',
#   u'query': u'coffee',
#   u'suggestedBounds': {u'ne': {u'lat': 40.72445115622661,
#     u'lng': -74.00383671516222},
#    u'sw': {u'lat': 40.72175149644116, u'lng': -74.00111827835521}},
#   u'suggestedFilters': {u'filters': [{u'key': u'price', u'name': u'$-$$$$'},
#     {u'key': u'openNow', u'name': u'Open now'}],
#    u'header': u'Tap to show:'},
#   u'suggestedRadius': 600,
#   u'totalResults': 68,
#   u'warning': {u'text': u'There aren\'t a lot of results for "coffee." Try something more general, reset your filters, or expand the search area.'}}}

# %%
# https://developer.foursquare.com/docs/api/checkins/details

# %%
import json, requests
url = 'https://api.foursquare.com/v2/checkins/54e51f11498ef4039fd5157a'

params = dict(
  client_id="1KNECHOW4ALXKWS4OWU2TEUZMPW0WUN1NORS2OUMWWBBCV4C",
  client_secret='O4QOOLKGDZK44DTBRPQIUDGO2Z4XQYYJQOJ0LN5E5FAQASMM',
  v='20170801',
  ll='40.7243,-74.0018',
limit=1
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {u'meta': {u'code': 400,
#   u'errorDetail': u'Invalid checkin id',
#   u'errorType': u'param_error',
#   u'requestId': u'5a95c6cd1ed2190ba7ee81a8'},
#  u'response': {}}

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/search'

params = dict(
  client_id="1KNECHOW4ALXKWS4OWU2TEUZMPW0WUN1NORS2OUMWWBBCV4C",
  client_secret='O4QOOLKGDZK44DTBRPQIUDGO2Z4XQYYJQOJ0LN5E5FAQASMM',
  v='20170801',
  near='New York, NY',
limit=10
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {u'meta': {u'code': 200, u'requestId': u'5a95c831351e3d52faa40f93'},
#  u'response': {u'confident': False,
#   u'geocode': {u'feature': {u'cc': u'US',
#     u'displayName': u'New York, NY, United States',
#     u'geometry': {u'bounds': {u'ne': {u'lat': 40.882214, u'lng': -73.907},
#       u'sw': {u'lat': 40.679548, u'lng': -74.047285}},
#      u'center': {u'lat': 40.742185, u'lng': -73.992602}},
#     u'highlightedName': u'<b>New York</b>, <b>NY</b>, United States',
#     u'id': u'geonameid:5128581',
#     u'longId': u'72057594043056517',
#     u'matchedName': u'New York, NY, United States',
#     u'name': u'New York',
#     u'slug': u'new-york-city-new-york',
#     u'woeType': 7},
#    u'parents': [],
#    u'what': u'',
#    u'where': u'new york ny'},
#   u'venues': [{u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d146941735',
#       u'name': u'Deli / Bodega',
#       u'pluralName': u'Delis / Bodegas',
#       u'primary': True,
#       u'shortName': u'Deli / Bodega'}],
#     u'contact': {},
#     u'delivery': {u'id': u'322016',
#      u'provider': {u'icon': {u'name': u'/delivery_provider_seamless_20180129.png',
#        u'prefix': u'https://igx.4sqi.net/img/general/cap/',
#        u'sizes': [40, 50]},
#       u'name': u'seamless'},
#      u'url': u'https://www.seamless.com/menu/essen-chelsea-699-6th-ave-new-york/322016?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322016'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 1,
#      u'groups': [{u'count': 1,
#        u'items': [],
#        u'name': u'Other people here',
#        u'type': u'others'}],
#      u'summary': u'One other person is here'},
#     u'id': u'56a8ffbb498e6d9f0e88052d',
#     u'location': {u'address': u'696 6th Avenue',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'at 22nd St',
#      u'formattedAddress': [u'696 6th Avenue (at 22nd St)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.74251926464117,
#        u'lng': -73.99318889229393}],
#      u'lat': 40.74251926464117,
#      u'lng': -73.99318889229393,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u"'Essen",
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 5632, u'tipCount': 25, u'usersCount': 1344},
#     u'url': u'http://essenslowfastfood.com',
#     u'verified': False},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d1d3941735',
#       u'name': u'Vegetarian / Vegan Restaurant',
#       u'pluralName': u'Vegetarian / Vegan Restaurants',
#       u'primary': True,
#       u'shortName': u'Vegetarian / Vegan'}],
#     u'contact': {u'facebook': u'735538026641957',
#      u'facebookName': u'by CHLOE. 22nd Street',
#      u'facebookUsername': u'byCHLOE22ndStreet',
#      u'formattedPhone': u'(347) 620-9622',
#      u'phone': u'3476209622',
#      u'twitter': u'eatbychloe'},
#     u'hasMenu': True,
#     u'hasPerk': False,
#     u'hereNow': {u'count': 2,
#      u'groups': [{u'count': 2,
#        u'items': [],
#        u'name': u'Other people here',
#        u'type': u'others'}],
#      u'summary': u'2 people are here'},
#     u'id': u'576bd714498e6b2020b3afb9',
#     u'location': {u'address': u'60 W 22nd St',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'5th and 6th Avenue',
#      u'formattedAddress': [u'60 W 22nd St (5th and 6th Avenue)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.7419722,
#        u'lng': -73.9929188}],
#      u'lat': 40.7419722,
#      u'lng': -73.9929188,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'menu': {u'anchor': u'View Menu',
#      u'label': u'Menu',
#      u'mobileUrl': u'https://foursquare.com/v/576bd714498e6b2020b3afb9/device_menu',
#      u'type': u'Menu',
#      u'url': u'https://foursquare.com/v/by-chloe/576bd714498e6b2020b3afb9/menu'},
#     u'name': u'by CHLOE',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 6963, u'tipCount': 123, u'usersCount': 3107},
#     u'url': u'http://eatbychloe.com',
#     u'verified': False},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d176941735',
#       u'name': u'Gym',
#       u'pluralName': u'Gyms',
#       u'primary': True,
#       u'shortName': u'Gym'}],
#     u'contact': {u'formattedPhone': u'(212) 989-2300',
#      u'phone': u'2129892300',
#      u'twitter': u'nyhrc'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#     u'id': u'4558b83bf964a5204b3d1fe3',
#     u'location': {u'address': u'60 W 23rd St',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'at 6th Ave',
#      u'formattedAddress': [u'60 W 23rd St (at 6th Ave)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'lat': 40.74257351738011,
#      u'lng': -73.99241203373882,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u'New York Health and Racquet Club',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 47366, u'tipCount': 59, u'usersCount': 3174},
#     u'storeId': u'',
#     u'url': u'http://nyhrc.com',
#     u'venuePage': {u'id': u'36095134'},
#     u'verified': True},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        u'suffix': u'.png'},
#       u'id': u'5744ccdfe4b0c0459246b4af',
#       u'name': u'Physical Therapist',
#       u'pluralName': u'Physical Therapists',
#       u'primary': True,
#       u'shortName': u'Physical Therapist'}],
#     u'contact': {u'formattedPhone': u'(212) 486-8573',
#      u'phone': u'2124868573',
#      u'twitter': u'finishlinept'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 1,
#      u'groups': [{u'count': 1,
#        u'items': [],
#        u'name': u'Other people here',
#        u'type': u'others'}],
#      u'summary': u'One other person is here'},
#     u'id': u'4b3f7fdaf964a520eda725e3',
#     u'location': {u'address': u'119 W 23rd St Ste 304',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'between 6th & 7th Ave.',
#      u'formattedAddress': [u'119 W 23rd St Ste 304 (between 6th & 7th Ave.)',
#       u'New York, NY 10011',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.74375188615124,
#        u'lng': -73.99309062619857}],
#      u'lat': 40.74375188615124,
#      u'lng': -73.99309062619857,
#      u'postalCode': u'10011',
#      u'state': u'NY'},
#     u'name': u'Finish Line Physical Therapy',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 3130, u'tipCount': 8, u'usersCount': 565},
#     u'storeId': u'',
#     u'url': u'http://finishlinept.com',
#     u'venuePage': {u'id': u'46669432'},
#     u'verified': True},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d1dc931735',
#       u'name': u'Tea Room',
#       u'pluralName': u'Tea Rooms',
#       u'primary': True,
#       u'shortName': u'Tea Room'}],
#     u'contact': {u'formattedPhone': u'(212) 229-0002',
#      u'phone': u'2122290002',
#      u'twitter': u'davidstea'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 1,
#      u'groups': [{u'count': 1,
#        u'items': [],
#        u'name': u'Other people here',
#        u'type': u'others'}],
#      u'summary': u'One other person is here'},
#     u'id': u'50b10a97e4b0c59eea49afef',
#     u'location': {u'address': u'688 Avenue of the Americas',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'at W 22nd St',
#      u'formattedAddress': [u'688 Avenue of the Americas (at W 22nd St)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.742089644779306,
#        u'lng': -73.99337760538255}],
#      u'lat': 40.742089644779306,
#      u'lng': -73.99337760538255,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u'DAVIDsTEA',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 4177, u'tipCount': 40, u'usersCount': 1795},
#     u'storeId': u'104',
#     u'url': u'http://www.davidstea.com',
#     u'venueChains': [{u'id': u'556a4310a7c8957d73d604a8'}],
#     u'verified': True},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d1e0931735',
#       u'name': u'Coffee Shop',
#       u'pluralName': u'Coffee Shops',
#       u'primary': True,
#       u'shortName': u'Coffee Shop'}],
#     u'contact': {u'facebook': u'118373244869944',
#      u'facebookName': u'Brooklyn Roasting Company',
#      u'facebookUsername': u'brooklynroastingcompany',
#      u'formattedPhone': u'(718) 855-1000',
#      u'phone': u'7188551000',
#      u'twitter': u'bklynroasting'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 1,
#      u'groups': [{u'count': 1,
#        u'items': [],
#        u'name': u'Other people here',
#        u'type': u'others'}],
#      u'summary': u'One other person is here'},
#     u'id': u'554ca083498efd419209c432',
#     u'location': {u'address': u'50 W 23rd St',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'btwn 5th & 6th Ave',
#      u'formattedAddress': [u'50 W 23rd St (btwn 5th & 6th Ave)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.742204,
#        u'lng': -73.991719}],
#      u'lat': 40.742204,
#      u'lng': -73.991719,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u'Brooklyn Roasting Company',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 10233, u'tipCount': 70, u'usersCount': 3010},
#     u'url': u'http://brooklynroasting.com',
#     u'verified': False},
#    {u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d124941735',
#       u'name': u'Office',
#       u'pluralName': u'Offices',
#       u'primary': True,
#       u'shortName': u'Office'}],
#     u'contact': {},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#     u'id': u'4f71cf66e4b09a1095f6d633',
#     u'location': {u'address': u'56 W 22nd St',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'6th Avenue',
#      u'formattedAddress': [u'56 W 22nd St (6th Avenue)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.74210763691991,
#        u'lng': -73.99269897675663}],
#      u'lat': 40.74210763691991,
#      u'lng': -73.99269897675663,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u'Aurify Brands HQ',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 31, u'tipCount': 0, u'usersCount': 16},
#     u'venueRatingBlacklisted': True,
#     u'verified': False},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d16c941735',
#       u'name': u'Burger Joint',
#       u'pluralName': u'Burger Joints',
#       u'primary': True,
#       u'shortName': u'Burgers'}],
#     u'contact': {u'formattedPhone': u'(212) 229-1404',
#      u'phone': u'2122291404',
#      u'twitter': u'newyorkburgerco'},
#     u'delivery': {u'id': u'64976',
#      u'provider': {u'icon': {u'name': u'/delivery_provider_seamless_20180129.png',
#        u'prefix': u'https://igx.4sqi.net/img/general/cap/',
#        u'sizes': [40, 50]},
#       u'name': u'seamless'},
#      u'url': u'https://www.seamless.com/menu/new-york-burger-co-678-6th-ave-new-york/64976?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=64976'},
#     u'hasMenu': True,
#     u'hasPerk': False,
#     u'hereNow': {u'count': 1,
#      u'groups': [{u'count': 1,
#        u'items': [],
#        u'name': u'Other people here',
#        u'type': u'others'}],
#      u'summary': u'One other person is here'},
#     u'id': u'49de5d52f964a52048601fe3',
#     u'location': {u'address': u'678 Sixth Avenue',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'btwn W 21st & W 22nd St',
#      u'formattedAddress': [u'678 Sixth Avenue (btwn W 21st & W 22nd St)',
#       u'New York, NY 10011',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.74168471226277,
#        u'lng': -73.9936975351119}],
#      u'lat': 40.74168471226277,
#      u'lng': -73.9936975351119,
#      u'postalCode': u'10011',
#      u'state': u'NY'},
#     u'menu': {u'anchor': u'View Menu',
#      u'label': u'Menu',
#      u'mobileUrl': u'https://foursquare.com/v/49de5d52f964a52048601fe3/device_menu',
#      u'type': u'Menu',
#      u'url': u'https://foursquare.com/v/new-york-burger-co--flatiron/49de5d52f964a52048601fe3/menu'},
#     u'name': u'New York Burger Co. - Flatiron',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 11468, u'tipCount': 111, u'usersCount': 6086},
#     u'storeId': u'',
#     u'url': u'http://www.newyorkburgerco.com',
#     u'venuePage': {u'id': u'160838058'},
#     u'verified': True},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d119951735',
#       u'name': u'Wine Shop',
#       u'pluralName': u'Wine Shops',
#       u'primary': True,
#       u'shortName': u'Wine Shop'}],
#     u'contact': {u'formattedPhone': u'(212) 206-7900',
#      u'phone': u'2122067900',
#      u'twitter': u'mhcwines'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#     u'id': u'4b32a8c6f964a5202e1125e3',
#     u'location': {u'address': u'61 W 23rd St',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'btw 5th & 6th Ave',
#      u'formattedAddress': [u'61 W 23rd St (btw 5th & 6th Ave)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.742599856402606,
#        u'lng': -73.99206435384662}],
#      u'lat': 40.742599856402606,
#      u'lng': -73.99206435384662,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u'Manor House Cellar',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 621, u'tipCount': 4, u'usersCount': 289},
#     u'url': u'http://www.manorhousecellar.com',
#     u'verified': False},
#    {u'allowMenuUrlEdit': True,
#     u'beenHere': {u'lastCheckinExpiredAt': 0},
#     u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        u'suffix': u'.png'},
#       u'id': u'4bf58dd8d48988d1c0941735',
#       u'name': u'Mediterranean Restaurant',
#       u'pluralName': u'Mediterranean Restaurants',
#       u'primary': True,
#       u'shortName': u'Mediterranean'}],
#     u'contact': {u'facebook': u'331606430263066',
#      u'facebookName': u'BITE',
#      u'facebookUsername': u'biteon14',
#      u'formattedPhone': u'(646) 649-2768',
#      u'phone': u'6466492768',
#      u'twitter': u'biteny'},
#     u'delivery': {u'id': u'323312',
#      u'provider': {u'icon': {u'name': u'/delivery_provider_seamless_20180129.png',
#        u'prefix': u'https://igx.4sqi.net/img/general/cap/',
#        u'sizes': [40, 50]},
#       u'name': u'seamless'},
#      u'url': u'https://www.seamless.com/menu/bite-22-62-w-22nd-st-new-york/323312?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=323312'},
#     u'hasPerk': False,
#     u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#     u'id': u'573363c2498eb18e283007f8',
#     u'location': {u'address': u'62 W 22nd St',
#      u'cc': u'US',
#      u'city': u'New York',
#      u'country': u'United States',
#      u'crossStreet': u'6th Ave',
#      u'formattedAddress': [u'62 W 22nd St (6th Ave)',
#       u'New York, NY 10010',
#       u'United States'],
#      u'labeledLatLngs': [{u'label': u'display',
#        u'lat': 40.742135733688905,
#        u'lng': -73.993066263182}],
#      u'lat': 40.742135733688905,
#      u'lng': -73.993066263182,
#      u'postalCode': u'10010',
#      u'state': u'NY'},
#     u'name': u'Bite',
#     u'referralId': u'v-1519765553',
#     u'specials': {u'count': 0, u'items': []},
#     u'stats': {u'checkinsCount': 2297, u'tipCount': 36, u'usersCount': 947},
#     u'url': u'http://www.bitenyc.com',
#     u'verified': False}]}}

# %%
foursquare_data_dict = dict(data)

# %%
#making dataframe from python data dictionary 
ny_df=pd.DataFrame.from_dict(foursquare_data_dict)

# %%
foursquare_data_dict.keys()
# Out:
# [u'meta', u'response']

# %%
# get one venue's information

foursquare_data_dict['response'].items()[2][1][0]
# Out:
# {u'allowMenuUrlEdit': True,
#  u'beenHere': {u'lastCheckinExpiredAt': 0},
#  u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#     u'suffix': u'.png'},
#    u'id': u'4bf58dd8d48988d146941735',
#    u'name': u'Deli / Bodega',
#    u'pluralName': u'Delis / Bodegas',
#    u'primary': True,
#    u'shortName': u'Deli / Bodega'}],
#  u'contact': {},
#  u'delivery': {u'id': u'322016',
#   u'provider': {u'icon': {u'name': u'/delivery_provider_seamless_20180129.png',
#     u'prefix': u'https://igx.4sqi.net/img/general/cap/',
#     u'sizes': [40, 50]},
#    u'name': u'seamless'},
#   u'url': u'https://www.seamless.com/menu/essen-chelsea-699-6th-ave-new-york/322016?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322016'},
#  u'hasPerk': False,
#  u'hereNow': {u'count': 1,
#   u'groups': [{u'count': 1,
#     u'items': [],
#     u'name': u'Other people here',
#     u'type': u'others'}],
#   u'summary': u'One other person is here'},
#  u'id': u'56a8ffbb498e6d9f0e88052d',
#  u'location': {u'address': u'696 6th Avenue',
#   u'cc': u'US',
#   u'city': u'New York',
#   u'country': u'United States',
#   u'crossStreet': u'at 22nd St',
#   u'formattedAddress': [u'696 6th Avenue (at 22nd St)',
#    u'New York, NY 10010',
#    u'United States'],
#   u'labeledLatLngs': [{u'label': u'display',
#     u'lat': 40.74251926464117,
#     u'lng': -73.99318889229393}],
#   u'lat': 40.74251926464117,
#   u'lng': -73.99318889229393,
#   u'postalCode': u'10010',
#   u'state': u'NY'},
#  u'name': u"'Essen",
#  u'referralId': u'v-1519765553',
#  u'specials': {u'count': 0, u'items': []},
#  u'stats': {u'checkinsCount': 5632, u'tipCount': 25, u'usersCount': 1344},
#  u'url': u'http://essenslowfastfood.com',
#  u'verified': False}

# %%
# put response data into the data dictionary
ny_df=pd.DataFrame.from_dict(foursquare_data_dict['response'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f8754acd0f64> in <module>()
#       1 # put response data into the data dictionary
# ----> 2 ny_df=pd.DataFrame.from_dict(foursquare_data_dict['response'])
#
# /Users/ceceliashao/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in from_dict(cls, data, orient, dtype)
#     849             raise ValueError('only recognize index or columns for orient')
#     850
# --> 851         return cls(data, index=index, columns=columns, dtype=dtype)
#     852
#     853     def to_dict(self, orient='dict'):
#
# /Users/ceceliashao/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# /Users/ceceliashao/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /Users/ceceliashao/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5494     # figure out the index, if necessary
#    5495     if index is None:
# -> 5496         index = extract_index(arrays)
#    5497     else:
#    5498         index = _ensure_index(index)
#
# /Users/ceceliashao/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in extract_index(data)
#    5545
#    5546             if have_dicts:
# -> 5547                 raise ValueError('Mixing dicts with non-Series may lead to '
#    5548                                  'ambiguous ordering.')
#    5549
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.
